# %% [markdown]
# # Python Learning Notes - Daily Log
#
# ## 05/22/2020
#
# ### Daily Objects
#
# 1. Setup a complete environment for Python learning and development
#
# 2. Get reference books
#
# 3. Start learning!
#
# ### Progress
#
# 1. Determine tutoring materials
#     - [Python 100 Days by jackfrued](https://github.com/jackfrued/Python-100-Days)
# 2. Pick reference books
#     - [Beginning Python: From Novice to Professional](https://www.amazon.com/Beginning-Python-Professional-Magnus-Hetland-ebook/dp/B06XGVVVMG)
#     - [Python Programming: An Introduction To Computer Science, Third Edition](https://www.amazon.com/Python-Programming-Introduction-Computer-Science/dp/1590282752)
# 3. Setup Python environment
#     - Environment management: [Anaconda](https://www.anaconda.com/products/individual)
#     - Main [IDE](https://www.codecademy.com/articles/what-is-an-ide)
#         - [Jupyter Notebook](https://jupyter.org/)
#         - [PyCharm](https://www.jetbrains.com/pycharm/)
#         - [Visual Studio Code](https://code.visualstudio.com/)
#     - Other IDE options
#         - [Sublime Text 3](https://www.sublimetext.com/)
#         - [Brackets](http://brackets.io/)
#         - [Atom](https://atom.io/)

# %% [markdown]
# ### Exercise 1
#
# Read the Zen of Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### Exercise 2
#
# Use the `turtle` package to draw figures
#
# When I was 7, my parents bought me a local-version of Nintendo's famous entertainment system:
#
# Subor Learning Machine (小霸王学习机）. It looks like this:
#
# ![Subor Learning Machine](images/05-22-2020/subor.jpg)
#
# It's pretty much a Nintendo with a keyboard and a bunch of game cards designed for "learning". One of them is called "[LOGO](https://en.wikipedia.org/wiki/Logo_(programming_language)", a programming language developed by Wally Feurzig and Seymour Papert in 1966. The main feature is to manipulate a turtle (brush) to draw any figure you want: letters, cars, mario characters.... As a kid, I found it so interesting that I gave it a special time slot between playing Contra and Nintendo World Cup. Surrounded by DOS-like interfaces, I was obsessed with the possibility of LOGO in creating beautiful graphs on my screen. One year later, Window 95 was launched and I couldn't keep myself from borrowing my auntie's computer, just for Minesweeper or Banana Wars. Windows made me officially say goodbye to DOS, but LOGO was one of the treasures that, sometimes, reminds me of the good of command lines. It also made me rethink of coding: those tedious command lines can actually create cool things.
#
# Below is a sample code of drawing "A3SR", which stands for the [Applied Statistics for Social Science Research](https://steinhardt.nyu.edu/programs/applied-statistics-social-science-research), a graduate program at New York University.

# %%
# Using turtle to draw "A3SR"
import turtle as t
# Setup pen size and color
t.pensize(4)
t.pencolor('red')
# Pen up: lift the pen so it won't draw anything
# Pen down: put down the pen to draw
t.penup()
t.backward(300)
t.pendown()

t.left(45)
t.forward(100)
t.right(90)
t.forward(50)
t.right(135)
t.forward(70.7)

t.penup()

t.backward(70.7)

t.pendown()

t.left(135)
t.forward(50)

t.penup()

t.left(45)
t.forward(30)

t.pendown()

t.forward(70)
t.left(90)
t.forward(35)
t.left(90)
t.forward(50)

t.penup()

t.backward(50)

t.pendown()

t.right(90)
t.forward(35)
t.left(90)
t.forward(70)

t.penup()

t.backward(117.5)

t.pendown()

t.backward(52.5)

t.penup()

t.forward(52.5)

t.pendown()

t.circle(17.5, 180) # radius: 17.5, anti-clockwise, draw 180 degrees
t.forward(35)
t.circle(-17.5, 180)
t.forward(52.5)

t.penup()

t.backward(100)

t.pendown()

t.right(90)
t.forward(71)
t.right(90)
t.forward(52.5)
t.circle(-17.5, 180)
t.forward(52.5)

t.penup()

t.backward(40)
t.left(120)

t.pendown()

t.forward(40.4)
t.left(60)
t.forward(70)

t.penup()

t.mainloop()

# %% [markdown]
# Here is the output:
#
# ![Use turtle to draw "A3SR"](images/05-22-2020/A3SR.jpg)
